# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
import numpy as np

#Input
X=np.array([[1,0,1,0],[1,0,1,1],[0,1,0,1]])

#Output
y=np.array([[1],[1],[0]])

model = Sequential()
model.add(Dense(40, input_dim=4, init='glorot_normal'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='glorot_normal'))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1)
model.compile(loss='mse', optimizer="adam", metrics=['accuracy'])

model.fit(X, y, epochs=100, batch_size=1)
score = model.evaluate(X, y, batch_size=1)
score
# Out:
# /Users/miladtoutounchian/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(40, input_dim=4, kernel_initializer="glorot_normal")`
#   del sys.path[0]
# /Users/miladtoutounchian/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="glorot_normal")`
#   from ipykernel import kernelapp as app
# Epoch 1/100
# 3/3 [==============================] - 0s 140ms/step - loss: 0.3286 - acc: 0.3333
# Epoch 2/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3209 - acc: 0.3333
# Epoch 3/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3155 - acc: 0.3333
# Epoch 4/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3067 - acc: 0.3333
# Epoch 5/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3041 - acc: 0.3333
# Epoch 6/100
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
import numpy as np

#Input
X=np.array([[1,0,1,0],[1,0,1,1],[0,1,0,1]])

#Output
y=np.array([[1],[1],[0]])

model = Sequential()
model.add(Dense(3, input_dim=4, init='glorot_normal'))
model.add(Activation('relu'))
model.add(Dense(1, init='glorot_normal'))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1)
model.compile(loss='mse', optimizer="adam", metrics=['accuracy'])

model.fit(X, y, epochs=100, batch_size=1)
score = model.evaluate(X, y, batch_size=1)
score
# Out:
# /Users/miladtoutounchian/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(3, input_dim=4, kernel_initializer="glorot_normal")`
#   del sys.path[0]
# /Users/miladtoutounchian/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="glorot_normal")`
#   from ipykernel import kernelapp as app
# Epoch 1/100
# 3/3 [==============================] - 0s 166ms/step - loss: 0.2544 - acc: 0.3333
# Epoch 2/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2539 - acc: 0.3333
# Epoch 3/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2537 - acc: 0.3333
# Epoch 4/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2535 - acc: 0.3333
# Epoch 5/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2532 - acc: 0.3333
# Epoch 6/100
# ...
