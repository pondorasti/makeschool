# %% [markdown]
# # Introduction to time series
# ## What is time?
#
# One definition of time as we percieve it is the observations of **events** as features of those events change. Think of a movie reel and how for evey frame a diffrecnt set of actions occur. These 'actions' can be quantified as features in any dataset based on the time in which they occur. What time series really seeks to point out is **what events occured at this point in time"**. This is incredibly powerful as time series is the backbone of nearly every industry. Here are some examples in which time series can be used:
# > - Looking at your github data to see which days you do what type of programming, for how long, ect
# > - In Fintech it's uses can be seen in studying past trends in crypto currency
# > - In the banking industry for fraud dectection and stocks and bonds trading
# > - In scientific analysis to study the effects of inputs in experiements over time
# > - Many more...

# %% [markdown]
# ## Discussion:
# ### Discuss how you conceptualize time asn well as give three examples of when measuring time in your everyday life could be interesting

# %% [markdown]
# ## Using Quandl for Time Series analysis
#
# The libray that we will use for retreiving financial, economic and sociology data is the python api for Quandl.
#
# Head over to https://www.quandl.com/ to  sign up for an account to get an API key first!
#
# Install this via anaconda with the following command. conda install -c anaconda quandl (you may have to use sudo)
#
# For today well be taking a look at Tesla's Stock data!

# %%
# quandl for financial data
import quandl

import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt

# Use your API Key

quandl.ApiConfig.api_key = ''


# Retrieve TSLA data from Quandl
tesla = quandl.get('WIKI/TSLA')

# %% [markdown]
# ### Lets take a look at the head of our dataframe to view what kind of data we will be working with.

# %%
tesla.head(5)
# Out:
#              Open     High    Low  Close      Volume  Ex-Dividend  \
# Date
# 2010-06-29  19.00  25.0000  17.54  23.89  18766300.0          0.0
# 2010-06-30  25.79  30.4192  23.30  23.83  17187100.0          0.0
# 2010-07-01  25.00  25.9200  20.27  21.96   8218800.0          0.0
# 2010-07-02  23.00  23.1000  18.71  19.20   5139800.0          0.0
# 2010-07-06  20.00  20.0000  15.83  16.11   6866900.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2010-06-29          1.0      19.00    25.0000     17.54       23.89
# 2010-06-30          1.0      25.79    30.4192     23.30       23.83
# 2010-07-01          1.0      25.00    25.9200     20.27       21.96
# 2010-07-02          1.0      23.00    23.1000     18.71       19.20
# 2010-07-06          1.0      20.00    20.0000     15.83       16.11
#
#             Adj. Volume
# Date
# 2010-06-29   18766300.0
# 2010-06-30   17187100.0
# 2010-07-01    8218800.0
# 2010-07-02    5139800.0
# 2010-07-06    6866900.0

# %% [markdown]
# ## Time series organization
#
# One of the first things you likely noticed is that instead of having the index just being a count, the index in this case is the actual timestamp. In certain fields or sciences, this may be the more prevalent form of working with times series. Other forms of time series may contain the temporal features as a regular column in your data.

# %%
tesla.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1949.000000  1949.000000  1949.000000  1949.000000  1.949000e+03
# mean    158.686482   161.315984   155.863583   158.641133  4.548989e+06
# std     111.101793   112.587258   109.427114   111.041316  4.185588e+06
# min      16.140000    16.630000    14.980000    15.800000  1.185000e+05
# 25%      31.600000    32.250000    30.870000    31.600000  1.350400e+06
# 50%     192.050000   195.120000   189.000000   192.690000  3.715161e+06
# 75%     240.490000   244.090000   235.670700   240.240000  6.076998e+06
# max     386.690000   389.610000   379.345000   385.000000  3.716390e+07
#
#        Ex-Dividend  Split Ratio    Adj. Open    Adj. High     Adj. Low  \
# count       1949.0       1949.0  1949.000000  1949.000000  1949.000000
# mean           0.0          1.0   158.686482   161.315984   155.863583
# std            0.0          0.0   111.101793   112.587258   109.427114
# min            0.0          1.0    16.140000    16.630000    14.980000
# 25%            0.0          1.0    31.600000    32.250000    30.870000
# 50%            0.0          1.0   192.050000   195.120000   189.000000
# 75%            0.0          1.0   240.490000   244.090000   235.670700
# max            0.0          1.0   386.690000   389.610000   379.345000
#
#         Adj. Close   Adj. Volume
# count  1949.000000  1.949000e+03
# mean    158.641133  4.548989e+06
# std     111.041316  4.185588e+06
# min      15.800000  1.185000e+05
# 25%      31.600000  1.350400e+06
# 50%     192.690000  3.715161e+06
# 75%     240.240000  6.076998e+06
# max     385.000000  3.716390e+07

# %% [markdown]
# ### Activity:
#
# Using google/ wikipiedia/ ect, pick 3 columns from this dataset and define them. This will give you a deeper undeerstanding of how your data works and what is realy being measured. A big part of what makes one more proficient at data science is being nosy....No seriously GET NOSY! Don't follow my usual advice to "Mind your business"

# %% [markdown]
# ## Time series and graphs
#
# One of the most frequent ways that you will see a time series represented is through the use of graphs, usually to track the change of a variable over time. in this case, it is the change of the Tesla stock over time.
#
# Lets look at a few just to get into the swing of it!
#
#
# To plot a time series we'll be using matplotlib.pyplot which we imported as "plt" as well.

# %% [markdown]
# ### Let's look at how the price of the stock changes over time!

# %%
plt.plot(tesla.index, tesla['Volume'].astype(int), 'r')
plt.title('Tesla Stock Volume by Year')
plt.ylabel('Number of shares traded (in 10\'s of millions)');
plt.xlabel('Time (in Years)');
plt.show();

# %% [markdown]
# ### Activity: using plt.plot, make 3 visualizations on time series. Based off of this, discuss with a neighboor any odd trends you see and try to explain them

# %% [markdown]
# ### Slicing and time intervals
# Viewing our data is all fine and dandy, but thats just wieing the entire set, what if we wanted to view this based on certain time intervals?
#
# Most times series are indexed based on what time the event in question took place. This differs from the bulk of your other data sets in that their indexes are just the number in which they appear in the dataset, this can be completely arbitrary. Time series are sliced pythonic-ly based on the that of occurence.
#
# Let's do some slicing just based on the year!

# %%
tesla['2010'].head(10)
# Out:
#                Open     High    Low  Close      Volume  Ex-Dividend  \
# Date
# 2010-06-29  19.0000  25.0000  17.54  23.89  18766300.0          0.0
# 2010-06-30  25.7900  30.4192  23.30  23.83  17187100.0          0.0
# 2010-07-01  25.0000  25.9200  20.27  21.96   8218800.0          0.0
# 2010-07-02  23.0000  23.1000  18.71  19.20   5139800.0          0.0
# 2010-07-06  20.0000  20.0000  15.83  16.11   6866900.0          0.0
# 2010-07-07  16.4000  16.6300  14.98  15.80   6921700.0          0.0
# 2010-07-08  16.1400  17.5200  15.57  17.46   7711400.0          0.0
# 2010-07-09  17.5800  17.9000  16.55  17.40   4050600.0          0.0
# 2010-07-12  17.9500  18.0700  17.00  17.05   2202500.0          0.0
# 2010-07-13  17.3938  18.6400  16.90  18.14   2680100.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2010-06-29          1.0    19.0000    25.0000     17.54       23.89
# 2010-06-30          1.0    25.7900    30.4192     23.30       23.83
# 2010-07-01          1.0    25.0000    25.9200     20.27       21.96
# 2010-07-02          1.0    23.0000    23.1000     18.71       19.20
# 2010-07-06          1.0    20.0000    20.0000     15.83       16.11
# 2010-07-07          1.0    16.4000    16.6300     14.98       15.80
# 2010-07-08          1.0    16.1400    17.5200     15.57       17.46
# 2010-07-09          1.0    17.5800    17.9000     16.55       17.40
# 2010-07-12          1.0    17.9500    18.0700     17.00       17.05
# 2010-07-13          1.0    17.3938    18.6400     16.90       18.14
#
#             Adj. Volume
# Date
# 2010-06-29   18766300.0
# 2010-06-30   17187100.0
# 2010-07-01    8218800.0
# 2010-07-02    5139800.0
# 2010-07-06    6866900.0
# 2010-07-07    6921700.0
# 2010-07-08    7711400.0
# 2010-07-09    4050600.0
# 2010-07-12    2202500.0
# 2010-07-13    2680100.0

# %% [markdown]
# ### Let's query the data just based off what happened in January of 2011

# %%
tesla['2011-1'].head(10)
# Out:
#              Open     High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 2011-01-03  26.84  26.9999  25.90  26.62  1283000.0          0.0          1.0
# 2011-01-04  26.66  26.9500  26.02  26.67  1187400.0          0.0          1.0
# 2011-01-05  26.48  26.9000  26.19  26.83  1446700.0          0.0          1.0
# 2011-01-06  26.83  28.0000  26.81  27.88  2061200.0          0.0          1.0
# 2011-01-07  28.00  28.5800  27.90  28.24  2247900.0          0.0          1.0
# 2011-01-10  28.17  28.6800  28.05  28.45  1342700.0          0.0          1.0
# 2011-01-11  28.59  28.7100  26.92  26.96  1710200.0          0.0          1.0
# 2011-01-12  27.01  27.3990  26.52  26.96   964400.0          0.0          1.0
# 2011-01-13  26.96  26.9700  26.16  26.22   723600.0          0.0          1.0
# 2011-01-14  26.15  26.5800  25.61  25.75  1192000.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 2011-01-03      26.84    26.9999     25.90       26.62    1283000.0
# 2011-01-04      26.66    26.9500     26.02       26.67    1187400.0
# 2011-01-05      26.48    26.9000     26.19       26.83    1446700.0
# 2011-01-06      26.83    28.0000     26.81       27.88    2061200.0
# 2011-01-07      28.00    28.5800     27.90       28.24    2247900.0
# 2011-01-10      28.17    28.6800     28.05       28.45    1342700.0
# 2011-01-11      28.59    28.7100     26.92       26.96    1710200.0
# 2011-01-12      27.01    27.3990     26.52       26.96     964400.0
# 2011-01-13      26.96    26.9700     26.16       26.22     723600.0
# 2011-01-14      26.15    26.5800     25.61       25.75    1192000.0

# %% [markdown]
# ### More precise slicing
#
# Most of your time series can be index in the following format.
#
# > month/day/year
#
#
# Let's slice our dataframe based on just thethe summer of 2015, shall we?

# %%
# Let's give summer a start date of May 1st
summer_start = '05/1/2015'

# Let's give it an end date of september 30th
summer_end = '09/30/2015'

# lets set it to another variable
tesla_summer = tesla[summer_start:summer_end]

# %%
tesla_summer.head(10)
# Out:
#               Open      High      Low   Close     Volume  Ex-Dividend  \
# Date
# 2015-05-01  229.94  231.7700  220.405  226.03  5281689.0          0.0
# 2015-05-04  228.18  234.7300  227.110  230.51  4434596.0          0.0
# 2015-05-05  237.76  239.5000  229.130  232.95  5796873.0          0.0
# 2015-05-06  234.10  234.4700  228.200  230.43  5270933.0          0.0
# 2015-05-07  221.00  237.4800  220.250  236.80  9455909.0          0.0
# 2015-05-08  235.99  238.4099  233.700  236.61  4668236.0          0.0
# 2015-05-11  236.29  242.8800  235.310  239.49  5672262.0          0.0
# 2015-05-12  240.11  246.3500  238.190  244.74  6363429.0          0.0
# 2015-05-13  247.61  248.3000  242.250  243.18  5440165.0          0.0
# 2015-05-14  244.82  244.8900  241.250  244.10  2895936.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2015-05-01          1.0     229.94   231.7700   220.405      226.03
# 2015-05-04          1.0     228.18   234.7300   227.110      230.51
# 2015-05-05          1.0     237.76   239.5000   229.130      232.95
# 2015-05-06          1.0     234.10   234.4700   228.200      230.43
# 2015-05-07          1.0     221.00   237.4800   220.250      236.80
# 2015-05-08          1.0     235.99   238.4099   233.700      236.61
# 2015-05-11          1.0     236.29   242.8800   235.310      239.49
# 2015-05-12          1.0     240.11   246.3500   238.190      244.74
# 2015-05-13          1.0     247.61   248.3000   242.250      243.18
# 2015-05-14          1.0     244.82   244.8900   241.250      244.10
#
#             Adj. Volume
# Date
# 2015-05-01    5281689.0
# 2015-05-04    4434596.0
# 2015-05-05    5796873.0
# 2015-05-06    5270933.0
# 2015-05-07    9455909.0
# 2015-05-08    4668236.0
# 2015-05-11    5672262.0
# 2015-05-12    6363429.0
# 2015-05-13    5440165.0
# 2015-05-14    2895936.0

# %% [markdown]
# ## Data base example
#
# Fintech is nice and all but we build products here!!! One of the ways that you'll be dealing with data in the industry and your own apps is your own user data. Knowing when, how many, or if your results indicate something odd is happening in your applications is a skill that makes things like testing, fraud detection, or even crashes and uptime.

# %% [markdown]
# The example we have below is a selection of user comments and button clicks observed in a fictional database over the last month of September.
# The columns contain the unique usernames, emails, comments, creation dates for those comments, as well as the number of button clicks this account has per minute. Well be using this data set to answer a few questions using the skills we've gains in time series, as well basic data manipulation.

# %%
user_comments_df = pd.read_csv('user_comments.csv')
user_comments_df
# Out:
#        id        user_name                             email  \
# 0       1         mcarass0           amingauld0@amazon.co.uk
# 1       2   bhessenthaler1                fputtan1@imgur.com
# 2       3      rschaffler2                 ojendrys2@home.pl
# 3       4          gbondy3         aspiniello3@wikimedia.org
# 4       5      disaaksohn4             rburchall4@zimbio.com
# 5       6           bewen5                   bhune5@youtu.be
# 6       7       fcullnean6               scornier6@issuu.com
# 7       8           fpayn7                  wprose7@uiuc.edu
# 8       9       gbernaldo8               mgotts8@addthis.com
# 9      10         ahainge9             lrestall9@gizmodo.com
# 10     11        rpittmana              nclaveringa@webs.com
# 11     12          tberryb         vruddimanb@macromedia.com
# 12     13        ccurtoisc      asleithc@theglobeandmail.com
# 13     14   bpiddlehintond             fbebbd@altervista.org
# 14     15           shamee              rcavnore@walmart.com
# 15     16       kspeechlyf         tcouronnef@prnewswire.com
# 16     17        osauntong                 cpetrakovg@un.org
# 17     18         wpantonh               bcrannageh@time.com
# 18     19         ctarpeyi                 bhandsi@europa.eu
# 19     20       aharesignj                  lrodriguezj@t.co
# 20     21         achildsk                   mcasonk@bbb.org
# 21     22         cfaivrel               lloydl@netvibes.com
# 22     23       mmeltetalm            cpolhillm@addtoany.com
# 23     24         acrownen             cduquesnayn@patch.com
# 24     25        mfarlambo               tdanahero@prlog.org
# 25     26         lrumneyp               pardyp@bandcamp.com
# 26     27        msherwynq                    wdranq@soup.io
# 27     28        charbackr               lfrowder@taobao.com
# 28     29       jhelstroms                  klevenes@hud.gov
# 29     30           lkeigt          cfarringtont@walmart.com
# ..    ...              ...                               ...
# 970   971      ttidcombeqy  iadanetqy@scientificamerican.com
# 971   972      sstuckleyqz         mdevereuxqz@homestead.com
# 972   973       mginglesr0            aoldfordr0@cbsnews.com
# 973   974  emarciskewskir1                igoggeyr1@webs.com
# 974   975         tmitror2              cgatrillr2@issuu.com
# 975   976     tguerrieror3                cbolensr3@time.com
# 976   977     twitteringr4               danscottr4@dmoz.org
# 977   978   gjakovijevicr5                vwarrackr5@cdc.gov
# 978   979        kminorsr6               dgocherr6@nymag.com
# 979   980       rbuddockr7         rbettanayr7@hostgator.com
# 980   981       vnisbithr8        eruddellr8@list-manage.com
# 981   982       hnuttallr9                 pbirtlesr9@goo.gl
# 982   983        kosoriora                gkoresra@globo.com
# 983   984    twhitecrossrb        tbrattonrb@ycombinator.com
# 984   985       cverrillrc                 aoliverrc@irs.gov
# 985   986        gbenkinrd         rbolsoverrd@rakuten.co.jp
# 986   987         egoadyre          bchurmsre@deviantart.com
# 987   988        agaydenrf            hformiglirf@dion.ne.jp
# 988   989         cbreemrg          bmonganrg@craigslist.org
# 989   990     bhandysiderh            amoffetrh@amazon.co.uk
# 990   991      kbaldettiri             vbirtri@123-reg.co.uk
# 991   992       gcockettrj          cottosenrj@biglobe.ne.jp
# 992   993        tpagittrk          ssandbachrk@virginia.edu
# 993   994        hkraussrl                 cbleirl@hc360.com
# 994   995         sdeboyrm           fmathwinrm@freewebs.com
# 995   996         tfrankrn       ssambathrn@wunderground.com
# 996   997        gwinsomro          gkupisro@squarespace.com
# 997   998       fpittolirp              akeeprp@newsvine.com
# 998   999      ebagshawerq           aoliverrq@bloomberg.com
# 999  1000         rflochrr            hgorckerr@engadget.com
#
#                                                comment         date_created  \
# 0    molestie lorem quisque ut erat curabitur gravi...  2018-09-13 06:09:40
# 1    felis sed lacus morbi sem mauris laoreet ut rh...  2018-09-07 08:17:22
# 2    vestibulum ante ipsum primis in faucibus orci ...  2018-09-10 08:24:07
# 3    ultrices posuere cubilia curae duis faucibus a...  2018-09-03 07:18:20
# 4    magna ac consequat metus sapien ut nunc vestib...  2018-09-17 23:20:40
# 5    nulla suscipit ligula in lacus curabitur at ip...  2018-09-17 00:20:35
# 6    nulla ut erat id mauris vulputate elementum nu...  2018-09-26 13:06:01
# 7    turpis nec euismod scelerisque quam turpis adi...  2018-09-28 02:19:05
# 8    in tempor turpis nec euismod scelerisque quam ...  2018-09-12 20:30:08
# 9    sed augue aliquam erat volutpat in congue etia...  2018-09-12 03:05:53
# 10   aliquam augue quam sollicitudin vitae consecte...  2018-09-24 22:58:52
# 11   eu nibh quisque id justo sit amet sapien digni...  2018-09-04 10:09:04
# 12   consectetuer eget rutrum at lorem integer tinc...  2018-09-22 18:48:36
# 13   platea dictumst etiam faucibus cursus urna ut ...  2018-09-08 11:23:21
# 14   leo maecenas pulvinar lobortis est phasellus s...  2018-09-28 03:16:00
# 15   ut ultrices vel augue vestibulum ante ipsum pr...  2018-09-04 02:23:42
# 16   ac nulla sed vel enim sit amet nunc viverra da...  2018-09-01 05:33:09
# 17   luctus rutrum nulla tellus in sagittis dui vel...  2018-09-05 13:44:41
# 18   pharetra magna vestibulum aliquet ultrices era...  2018-09-24 20:37:55
# 19   suscipit ligula in lacus curabitur at ipsum ac...  2018-09-25 06:35:51
# 20   convallis eget eleifend luctus ultricies eu ni...  2018-09-28 11:18:42
# 21   elit proin risus praesent lectus vestibulum qu...  2018-09-28 19:56:08
# 22   amet consectetuer adipiscing elit proin risus ...  2018-09-08 17:07:56
# 23   erat curabitur gravida nisi at nibh in hac hab...  2018-09-21 00:09:03
# 24   ipsum aliquam non mauris morbi non lectus aliq...  2018-09-27 06:44:29
# 25   sit amet eros suspendisse accumsan tortor quis...  2018-09-12 18:07:09
# 26   pede lobortis ligula sit amet eleifend pede li...  2018-09-04 12:13:57
# 27   suspendisse ornare consequat lectus in est ris...  2018-09-24 01:31:03
# 28   lobortis vel dapibus at diam nam tristique tor...  2018-09-26 01:41:14
# 29   quis justo maecenas rhoncus aliquam lacus morb...  2018-09-07 19:51:58
# ..                                                 ...                  ...
# 970  sem praesent id massa id nisl venenatis lacini...  2018-09-15 19:25:54
# 971  amet lobortis sapien sapien non mi integer ac ...  2018-09-07 06:14:49
# 972  magnis dis parturient montes nascetur ridiculu...  2018-09-04 04:47:46
# 973  dui nec nisi volutpat eleifend donec ut dolor ...  2018-09-05 18:29:53
# 974  id ligula suspendisse ornare consequat lectus ...  2018-09-17 08:32:47
# 975  fusce posuere felis sed lacus morbi sem mauris...  2018-09-06 02:27:45
# 976  vehicula condimentum curabitur in libero ut ma...  2018-09-07 19:11:24
# 977  mi integer ac neque duis bibendum morbi non qu...  2018-09-16 10:41:05
# 978  augue quam sollicitudin vitae consectetuer ege...  2018-09-07 00:00:31
# 979  praesent id massa id nisl venenatis lacinia ae...  2018-09-07 05:33:25
# 980  tempus vivamus in felis eu sapien cursus vesti...  2018-09-15 13:31:22
# 981  congue elementum in hac habitasse platea dictu...  2018-09-29 12:03:23
# 982  lacus at turpis donec posuere metus vitae ipsu...  2018-09-01 11:03:06
# 983  vivamus tortor duis mattis egestas metus aenea...  2018-09-04 13:07:50
# 984  lacus at turpis donec posuere metus vitae ipsu...  2018-09-05 05:53:39
# 985  sed accumsan felis ut at dolor quis odio conse...  2018-09-09 02:20:47
# 986  lobortis ligula sit amet eleifend pede libero ...  2018-09-20 21:48:48
# 987  vestibulum ante ipsum primis in faucibus orci ...  2018-09-23 17:51:29
# 988  mi in porttitor pede justo eu massa donec dapi...  2018-09-18 03:16:51
# 989  justo in hac habitasse platea dictumst etiam f...  2018-09-07 01:38:45
# 990  pretium iaculis diam erat fermentum justo nec ...  2018-09-07 11:37:37
# 991  eleifend quam a odio in hac habitasse platea d...  2018-09-15 08:29:12
# 992  dictumst morbi vestibulum velit id pretium iac...  2018-09-12 13:43:34
# 993  phasellus id sapien in sapien iaculis congue v...  2018-09-09 01:21:10
# 994  etiam justo etiam pretium iaculis justo in hac...  2018-09-11 09:14:38
# 995  praesent blandit nam nulla integer pede justo ...  2018-09-01 21:53:04
# 996  justo pellentesque viverra pede ac diam cras p...  2018-09-09 09:04:14
# 997  felis sed interdum venenatis turpis enim bland...  2018-09-15 02:43:05
# 998  libero non mattis pulvinar nulla pede ullamcor...  2018-09-19 16:00:21
# 999  etiam vel augue vestibulum rutrum rutrum neque...  2018-09-29 13:17:55
#
#      btn_clicks_per_min
# 0                    12
# 1                    25
# 2                    26
# 3                    32
# 4                    20
# 5                    27
# 6                    25
# 7                     7
# 8                     6
# 9                    41
# 10                   42
# 11                   32
# 12                   21
# 13                   24
# 14                   29
# 15                   34
# 16                   32
# 17                    3
# 18                   29
# 19                   13
# 20                   18
# 21                   26
# 22                   14
# 23                   28
# 24                   40
# 25                   13
# 26                   33
# 27                   15
# 28                   26
# 29                   28
# ..                  ...
# 970                   6
# 971                   7
# 972                  41
# 973                  10
# 974                  18
# 975                  35
# 976                  14
# 977                   2
# 978                   9
# 979                   8
# 980                  42
# 981                  35
# 982                  25
# 983                  32
# 984                  18
# 985                  25
# 986                  38
# 987                  23
# 988                   4
# 989                  34
# 990                  35
# 991                   8
# 992                  25
# 993                   1
# 994                  43
# 995                  34
# 996                  32
# 997                  23
# 998                  19
# 999                   1
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## Challenges
#
# 1. How many government accounts have made comments in the month this dataset covers?
# 2. What day had the most comments? which had the least?
# 3. We'll define a fradulent account as one that has made more than 40 average clicks per minute. how many fraud accounts are there in this dataset? How many are students in college? Do non goverment accounts have a higher probability of being fraud vs the probability of being fraudulent if they are non-goverment accounts?
# 4. How many comments mention 'gradiva' and were there more mentions during the day or night?
# 5. Was the latter half of the month more popular for commenting than the earlier half?
# 6. What is the average length of a comment coming from people in the irs?

# %%
# Here is an example of how to use the pandas.Series.str.contains() method to parse every string in a series and return the rows containing certain data. This will help you out with some of the exercises above

user_comments_df[(user_comments_df['user_name'].str.contains('this',regex=False))]
# Out:
#       id     user_name                  email  \
# 660  661  amathissenic  tvardonic@comcast.net
#
#                                                comment         date_created  \
# 660  quam sollicitudin vitae consectetuer eget rutr...  2018-09-25 02:46:38
#
#      btn_clicks_per_min
# 660                  20
